# %% [markdown]
# read https://docs.pytorch.org/vision/stable/transforms.html

# %% [markdown]
# how cnn works:
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/watch?v=3bo8S1pAbqk

# %% [markdown]
# minibatches https://www.youtube.com/watch?v=4qJaSmvhxi8

# %% [markdown]
# https://docs.pytorch.org/docs/stable/data.html
